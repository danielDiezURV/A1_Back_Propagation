# %%
###··· TURBINE DATASET ···### 
# Part 1: Selecting and analyzing the dataset
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


#Load the dataset
turbine_dataset = pd.read_csv("A1-turbine.txt", sep='\t', header=0)
x = turbine_dataset[['#height_over_sea_level', 'fall', 'net_fall', 'flow']] 
y = turbine_dataset[["power_of_hydroelectrical_turbine"]]
#Scale the data
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
y_scaled = scaler.fit_transform(y)
validation_percentage=0.15

# %%
from matplotlib import pyplot as plt
from MyNeuralNetwork import MyNeuralNetwork

#Create the neural network and train
nn = MyNeuralNetwork(layers=[x_scaled.shape[1],9,5,1], nEpochs=200, learning_rate=0.001, momentum=0.1, activation='relu', validation_set=validation_percentage)
nn.fit(x_scaled, y_scaled)

# Optional: Plot the evolution of the training and validation errors  
(loss, val_loss) = nn.loss_epochs()
plt.plot(loss)
plt.plot(val_loss)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch  1 / 200
# ============= [loss:  0.137  - mae:  0.3046  - val_loss:  0.2109  - val_mae:   0.3891 ]
# Epoch  2 / 200
# ============= [loss:  0.1263  - mae:  0.2949  - val_loss:  0.1736  - val_mae:   0.3625 ]
# Epoch  3 / 200
# ============= [loss:  0.1236  - mae:  0.2922  - val_loss:  0.1623  - val_mae:   0.3529 ]
# Epoch  4 / 200
# ============= [loss:  0.1217  - mae:  0.2903  - val_loss:  0.1574  - val_mae:   0.348 ]
# Epoch  5 / 200
# ============= [loss:  0.1202  - mae:  0.2887  - val_loss:  0.1535  - val_mae:   0.3442 ]
# Epoch  6 / 200
# ============= [loss:  0.119  - mae:  0.2872  - val_loss:  0.1506  - val_mae:   0.341 ]
# Epoch  7 / 200
# ============= [loss:  0.1173  - mae:  0.2857  - val_loss:  0.1509  - val_mae:   0.3408 ]
# Epoch  8 / 200
# ============= [loss:  0.1161  - mae:  0.2843  - val_loss:  0.1501  - val_mae:   0.3399 ]
# Epoch  9 / 200
# ============= [loss:  0.1148  - mae:  0.2828  - val_loss:  0.1483  - val_mae:   0.3378 ]
# Epoch  10 / 200
# ============= [loss:  0.1138  - mae:  0.2814  - val_loss:  0.1457  - val_mae:   0.3347 ]
# Epoch  11 / 200
# ============= [loss:  0.1127  - mae:  0.2804  - val_loss:  0.1458  - val_mae:   0.3349 ]
# Epoch  12 / 200
# ============= [loss:  0.1115  - mae:  0.2789  - val_loss:  0.1435  - val_mae:   0.3324 ]
# Epoch  13 / 200
# ============= [loss:  0.1105  - mae:  0.2776  - val_loss:  0.1423  - val_mae:   0.3309 ]
# Epoch  14 / 200
# ============= [loss:  0.1094  - mae:  0.2763  - val_loss:  0.1402  - val_mae:   0.3285 ]
# Epoch  15 / 200
# ============= [loss:  0.1084  - mae:  0.2751  - val_loss:  0.139  - val_mae:   0.3272 ]
# Epoch  16 / 200
# ============= [loss:  0.1075  - mae:  0.2738  - val_loss:  0.1365  - val_mae:   0.3242 ]
# Epoch  17 / 200
# ============= [loss:  0.1066  - mae:  0.2728  - val_loss:  0.136  - val_mae:   0.3238 ]
# Epoch  18 / 200
# ============= [loss:  0.1056  - mae:  0.2712  - val_loss:  0.133  - val_mae:   0.32 ]
# Epoch  19 / 200
# ============= [loss:  0.1046  - mae:  0.2701  - val_loss:  0.133  - val_mae:   0.3201 ]
# Epoch  20 / 200
# ============= [loss:  0.1036  - mae:  0.2691  - val_loss:  0.1323  - val_mae:   0.3194 ]
# Epoch  21 / 200
# ============= [loss:  0.1026  - mae:  0.2675  - val_loss:  0.1298  - val_mae:   0.316 ]
# Epoch  22 / 200
# ============= [loss:  0.1016  - mae:  0.2659  - val_loss:  0.1272  - val_mae:   0.3123 ]
# Epoch  23 / 200
# ============= [loss:  0.1006  - mae:  0.2653  - val_loss:  0.1283  - val_mae:   0.314 ]
# Epoch  24 / 200
# ============= [loss:  0.0995  - mae:  0.2638  - val_loss:  0.1269  - val_mae:   0.3121 ]
# Epoch  25 / 200
# ============= [loss:  0.0983  - mae:  0.2621  - val_loss:  0.1251  - val_mae:   0.3095 ]
# Epoch  26 / 200
# ============= [loss:  0.0973  - mae:  0.26  - val_loss:  0.1213  - val_mae:   0.3038 ]
# Epoch  27 / 200
# ============= [loss:  0.0961  - mae:  0.2585  - val_loss:  0.1202  - val_mae:   0.3025 ]
# Epoch  28 / 200
# ============= [loss:  0.0952  - mae:  0.257  - val_loss:  0.1181  - val_mae:   0.2992 ]
# Epoch  29 / 200
# ============= [loss:  0.0938  - mae:  0.256  - val_loss:  0.1185  - val_mae:   0.3002 ]
# Epoch  30 / 200
# ============= [loss:  0.0927  - mae:  0.254  - val_loss:  0.116  - val_mae:   0.2965 ]
# Epoch  31 / 200
# ============= [loss:  0.0915  - mae:  0.2527  - val_loss:  0.1152  - val_mae:   0.2953 ]
# Epoch  32 / 200
# ============= [loss:  0.0902  - mae:  0.2518  - val_loss:  0.1162  - val_mae:   0.2961 ]
# Epoch  33 / 200
# ============= [loss:  0.0889  - mae:  0.2499  - val_loss:  0.114  - val_mae:   0.2929 ]
# Epoch  34 / 200
# ============= [loss:  0.0878  - mae:  0.2482  - val_loss:  0.1119  - val_mae:   0.2901 ]
# Epoch  35 / 200
# ============= [loss:  0.0867  - mae:  0.246  - val_loss:  0.1089  - val_mae:   0.2857 ]
# Epoch  36 / 200
# ============= [loss:  0.0856  - mae:  0.2447  - val_loss:  0.1076  - val_mae:   0.284 ]
# Epoch  37 / 200
# ============= [loss:  0.0845  - mae:  0.2439  - val_loss:  0.1067  - val_mae:   0.2829 ]
# Epoch  38 / 200
# ============= [loss:  0.0835  - mae:  0.241  - val_loss:  0.1031  - val_mae:   0.2771 ]
# Epoch  39 / 200
# ============= [loss:  0.0823  - mae:  0.2396  - val_loss:  0.1015  - val_mae:   0.2751 ]
# Epoch  40 / 200
# ============= [loss:  0.0811  - mae:  0.2384  - val_loss:  0.0999  - val_mae:   0.2734 ]
# Epoch  41 / 200
# ============= [loss:  0.0799  - mae:  0.2374  - val_loss:  0.0988  - val_mae:   0.2719 ]
# Epoch  42 / 200
# ============= [loss:  0.0787  - mae:  0.2359  - val_loss:  0.0975  - val_mae:   0.27 ]
# Epoch  43 / 200
# ============= [loss:  0.0773  - mae:  0.2333  - val_loss:  0.0947  - val_mae:   0.266 ]
# Epoch  44 / 200
# ============= [loss:  0.0761  - mae:  0.232  - val_loss:  0.0937  - val_mae:   0.2644 ]
# Epoch  45 / 200
# ============= [loss:  0.0748  - mae:  0.2304  - val_loss:  0.0922  - val_mae:   0.2629 ]
# Epoch  46 / 200
# ============= [loss:  0.0734  - mae:  0.227  - val_loss:  0.0885  - val_mae:   0.2566 ]
# Epoch  47 / 200
# ============= [loss:  0.0722  - mae:  0.2253  - val_loss:  0.0866  - val_mae:   0.2539 ]
# Epoch  48 / 200
# ============= [loss:  0.0709  - mae:  0.223  - val_loss:  0.0843  - val_mae:   0.2503 ]
# Epoch  49 / 200
# ============= [loss:  0.0696  - mae:  0.2209  - val_loss:  0.0822  - val_mae:   0.247 ]
# Epoch  50 / 200
# ============= [loss:  0.0682  - mae:  0.2191  - val_loss:  0.0805  - val_mae:   0.245 ]
# Epoch  51 / 200
# ============= [loss:  0.0668  - mae:  0.217  - val_loss:  0.0787  - val_mae:   0.2426 ]
# Epoch  52 / 200
# ============= [loss:  0.0657  - mae:  0.2138  - val_loss:  0.0757  - val_mae:   0.2363 ]
# Epoch  53 / 200
# ============= [loss:  0.0643  - mae:  0.2139  - val_loss:  0.0761  - val_mae:   0.2405 ]
# Epoch  54 / 200
# ============= [loss:  0.0626  - mae:  0.2101  - val_loss:  0.0725  - val_mae:   0.2334 ]
# Epoch  55 / 200
# ============= [loss:  0.0613  - mae:  0.2083  - val_loss:  0.0711  - val_mae:   0.2321 ]
# Epoch  56 / 200
# ============= [loss:  0.0598  - mae:  0.2057  - val_loss:  0.0689  - val_mae:   0.2284 ]
# Epoch  57 / 200
# ============= [loss:  0.0583  - mae:  0.2025  - val_loss:  0.0661  - val_mae:   0.223 ]
# Epoch  58 / 200
# ============= [loss:  0.0569  - mae:  0.2001  - val_loss:  0.0642  - val_mae:   0.2204 ]
# Epoch  59 / 200
# ============= [loss:  0.0553  - mae:  0.1979  - val_loss:  0.0625  - val_mae:   0.2185 ]
# Epoch  60 / 200
# ============= [loss:  0.0538  - mae:  0.1947  - val_loss:  0.0599  - val_mae:   0.2134 ]
# Epoch  61 / 200
# ============= [loss:  0.0525  - mae:  0.191  - val_loss:  0.0572  - val_mae:   0.2063 ]
# Epoch  62 / 200
# ============= [loss:  0.0507  - mae:  0.1884  - val_loss:  0.0553  - val_mae:   0.2039 ]
# Epoch  63 / 200
# ============= [loss:  0.0493  - mae:  0.1851  - val_loss:  0.0532  - val_mae:   0.1988 ]
# Epoch  64 / 200
# ============= [loss:  0.0474  - mae:  0.1823  - val_loss:  0.0516  - val_mae:   0.1967 ]
# Epoch  65 / 200
# ============= [loss:  0.0459  - mae:  0.1791  - val_loss:  0.0494  - val_mae:   0.1919 ]
# Epoch  66 / 200
# ============= [loss:  0.0442  - mae:  0.1759  - val_loss:  0.0475  - val_mae:   0.1877 ]
# Epoch  67 / 200
# ============= [loss:  0.0426  - mae:  0.1725  - val_loss:  0.0453  - val_mae:   0.1828 ]
# Epoch  68 / 200
# ============= [loss:  0.0408  - mae:  0.1699  - val_loss:  0.044  - val_mae:   0.1809 ]
# Epoch  69 / 200
# ============= [loss:  0.039  - mae:  0.1665  - val_loss:  0.0423  - val_mae:   0.1771 ]
# Epoch  70 / 200
# ============= [loss:  0.0371  - mae:  0.1617  - val_loss:  0.0397  - val_mae:   0.1702 ]
# Epoch  71 / 200
# ============= [loss:  0.0353  - mae:  0.158  - val_loss:  0.0378  - val_mae:   0.1658 ]
# Epoch  72 / 200
# ============= [loss:  0.0335  - mae:  0.1538  - val_loss:  0.0355  - val_mae:   0.1601 ]
# Epoch  73 / 200
# ============= [loss:  0.0318  - mae:  0.1503  - val_loss:  0.0337  - val_mae:   0.156 ]
# Epoch  74 / 200
# ============= [loss:  0.0301  - mae:  0.1456  - val_loss:  0.0312  - val_mae:   0.1494 ]
# Epoch  75 / 200
# ============= [loss:  0.0284  - mae:  0.1412  - val_loss:  0.029  - val_mae:   0.1438 ]
# Epoch  76 / 200
# ============= [loss:  0.0266  - mae:  0.1373  - val_loss:  0.027  - val_mae:   0.1398 ]
# Epoch  77 / 200
# ============= [loss:  0.0249  - mae:  0.132  - val_loss:  0.0247  - val_mae:   0.1325 ]
# Epoch  78 / 200
# ============= [loss:  0.0233  - mae:  0.1285  - val_loss:  0.0234  - val_mae:   0.1304 ]
# Epoch  79 / 200
# ============= [loss:  0.0215  - mae:  0.1227  - val_loss:  0.021  - val_mae:   0.1226 ]
# Epoch  80 / 200
# ============= [loss:  0.02  - mae:  0.1184  - val_loss:  0.0195  - val_mae:   0.1185 ]
# Epoch  81 / 200
# ============= [loss:  0.0186  - mae:  0.114  - val_loss:  0.0177  - val_mae:   0.1129 ]
# Epoch  82 / 200
# ============= [loss:  0.0171  - mae:  0.1087  - val_loss:  0.0154  - val_mae:   0.1041 ]
# Epoch  83 / 200
# ============= [loss:  0.0159  - mae:  0.1045  - val_loss:  0.0137  - val_mae:   0.099 ]
# Epoch  84 / 200
# ============= [loss:  0.0148  - mae:  0.1007  - val_loss:  0.0122  - val_mae:   0.0917 ]
# Epoch  85 / 200
# ============= [loss:  0.0137  - mae:  0.0964  - val_loss:  0.0109  - val_mae:   0.0871 ]
# Epoch  86 / 200
# ============= [loss:  0.0127  - mae:  0.0924  - val_loss:  0.0097  - val_mae:   0.0822 ]
# Epoch  87 / 200
# ============= [loss:  0.0115  - mae:  0.0887  - val_loss:  0.0085  - val_mae:   0.0761 ]
# Epoch  88 / 200
# ============= [loss:  0.0107  - mae:  0.0847  - val_loss:  0.0076  - val_mae:   0.0728 ]
# Epoch  89 / 200
# ============= [loss:  0.01  - mae:  0.0821  - val_loss:  0.0069  - val_mae:   0.0708 ]
# Epoch  90 / 200
# ============= [loss:  0.0095  - mae:  0.0788  - val_loss:  0.0063  - val_mae:   0.0675 ]
# Epoch  91 / 200
# ============= [loss:  0.009  - mae:  0.0772  - val_loss:  0.0059  - val_mae:   0.0662 ]
# Epoch  92 / 200
# ============= [loss:  0.0088  - mae:  0.0728  - val_loss:  0.0056  - val_mae:   0.0618 ]
# Epoch  93 / 200
# ============= [loss:  0.0084  - mae:  0.0755  - val_loss:  0.0054  - val_mae:   0.0651 ]
# Epoch  94 / 200
# ============= [loss:  0.0081  - mae:  0.0712  - val_loss:  0.005  - val_mae:   0.0602 ]
# Epoch  95 / 200
# ============= [loss:  0.0079  - mae:  0.0715  - val_loss:  0.0048  - val_mae:   0.0608 ]
# Epoch  96 / 200
# ============= [loss:  0.0077  - mae:  0.0699  - val_loss:  0.0046  - val_mae:   0.0592 ]
# Epoch  97 / 200
# ============= [loss:  0.0075  - mae:  0.068  - val_loss:  0.0044  - val_mae:   0.0571 ]
# Epoch  98 / 200
# ============= [loss:  0.0073  - mae:  0.0676  - val_loss:  0.0043  - val_mae:   0.0568 ]
# Epoch  99 / 200
# ============= [loss:  0.0071  - mae:  0.0682  - val_loss:  0.0043  - val_mae:   0.0577 ]
# Epoch  100 / 200
# ============= [loss:  0.007  - mae:  0.0689  - val_loss:  0.0043  - val_mae:   0.0586 ]
# Epoch  101 / 200
# ============= [loss:  0.0068  - mae:  0.0639  - val_loss:  0.0038  - val_mae:   0.0527 ]
# Epoch  102 / 200
# ============= [loss:  0.0066  - mae:  0.0651  - val_loss:  0.0039  - val_mae:   0.0544 ]
# Epoch  103 / 200
# ============= [loss:  0.0064  - mae:  0.0622  - val_loss:  0.0036  - val_mae:   0.0509 ]
# Epoch  104 / 200
# ============= [loss:  0.0063  - mae:  0.0626  - val_loss:  0.0036  - val_mae:   0.0515 ]
# Epoch  105 / 200
# ============= [loss:  0.0061  - mae:  0.062  - val_loss:  0.0035  - val_mae:   0.0508 ]
# Epoch  106 / 200
# ============= [loss:  0.006  - mae:  0.0604  - val_loss:  0.0033  - val_mae:   0.0488 ]
# Epoch  107 / 200
# ============= [loss:  0.0059  - mae:  0.0613  - val_loss:  0.0034  - val_mae:   0.0502 ]
# Epoch  108 / 200
# ============= [loss:  0.0057  - mae:  0.0614  - val_loss:  0.0034  - val_mae:   0.0503 ]
# Epoch  109 / 200
# ============= [loss:  0.0056  - mae:  0.0592  - val_loss:  0.0031  - val_mae:   0.0477 ]
# Epoch  110 / 200
# ============= [loss:  0.0054  - mae:  0.0581  - val_loss:  0.003  - val_mae:   0.0463 ]
# Epoch  111 / 200
# ============= [loss:  0.0053  - mae:  0.0576  - val_loss:  0.003  - val_mae:   0.0458 ]
# Epoch  112 / 200
# ============= [loss:  0.0052  - mae:  0.0566  - val_loss:  0.0029  - val_mae:   0.0445 ]
# Epoch  113 / 200
# ============= [loss:  0.0051  - mae:  0.0552  - val_loss:  0.0028  - val_mae:   0.0428 ]
# Epoch  114 / 200
# ============= [loss:  0.005  - mae:  0.0565  - val_loss:  0.0028  - val_mae:   0.0447 ]
# Epoch  115 / 200
# ============= [loss:  0.0049  - mae:  0.0555  - val_loss:  0.0027  - val_mae:   0.0434 ]
# Epoch  116 / 200
# ============= [loss:  0.0048  - mae:  0.0548  - val_loss:  0.0026  - val_mae:   0.0425 ]
# Epoch  117 / 200
# ============= [loss:  0.0046  - mae:  0.053  - val_loss:  0.0025  - val_mae:   0.0404 ]
# Epoch  118 / 200
# ============= [loss:  0.0046  - mae:  0.0522  - val_loss:  0.0024  - val_mae:   0.0396 ]
# Epoch  119 / 200
# ============= [loss:  0.0045  - mae:  0.0545  - val_loss:  0.0026  - val_mae:   0.0429 ]
# Epoch  120 / 200
# ============= [loss:  0.0044  - mae:  0.0517  - val_loss:  0.0024  - val_mae:   0.0393 ]
# Epoch  121 / 200
# ============= [loss:  0.0043  - mae:  0.0513  - val_loss:  0.0023  - val_mae:   0.0389 ]
# Epoch  122 / 200
# ============= [loss:  0.0042  - mae:  0.0503  - val_loss:  0.0023  - val_mae:   0.0379 ]
# Epoch  123 / 200
# ============= [loss:  0.0041  - mae:  0.0494  - val_loss:  0.0022  - val_mae:   0.0371 ]
# Epoch  124 / 200
# ============= [loss:  0.004  - mae:  0.0499  - val_loss:  0.0022  - val_mae:   0.0378 ]
# Epoch  125 / 200
# ============= [loss:  0.0039  - mae:  0.0495  - val_loss:  0.0022  - val_mae:   0.0376 ]
# Epoch  126 / 200
# ============= [loss:  0.0039  - mae:  0.0488  - val_loss:  0.0021  - val_mae:   0.037 ]
# Epoch  127 / 200
# ============= [loss:  0.0038  - mae:  0.0476  - val_loss:  0.0021  - val_mae:   0.0358 ]
# Epoch  128 / 200
# ============= [loss:  0.0037  - mae:  0.0473  - val_loss:  0.002  - val_mae:   0.0356 ]
# Epoch  129 / 200
# ============= [loss:  0.0036  - mae:  0.0477  - val_loss:  0.002  - val_mae:   0.0362 ]
# Epoch  130 / 200
# ============= [loss:  0.0036  - mae:  0.048  - val_loss:  0.002  - val_mae:   0.0365 ]
# Epoch  131 / 200
# ============= [loss:  0.0035  - mae:  0.0462  - val_loss:  0.0019  - val_mae:   0.0348 ]
# Epoch  132 / 200
# ============= [loss:  0.0035  - mae:  0.0468  - val_loss:  0.002  - val_mae:   0.0356 ]
# Epoch  133 / 200
# ============= [loss:  0.0034  - mae:  0.0464  - val_loss:  0.0019  - val_mae:   0.0352 ]
# Epoch  134 / 200
# ============= [loss:  0.0034  - mae:  0.0455  - val_loss:  0.0019  - val_mae:   0.0345 ]
# Epoch  135 / 200
# ============= [loss:  0.0033  - mae:  0.0459  - val_loss:  0.0019  - val_mae:   0.035 ]
# Epoch  136 / 200
# ============= [loss:  0.0032  - mae:  0.045  - val_loss:  0.0019  - val_mae:   0.0342 ]
# Epoch  137 / 200
# ============= [loss:  0.0032  - mae:  0.0453  - val_loss:  0.0019  - val_mae:   0.0346 ]
# Epoch  138 / 200
# ============= [loss:  0.0032  - mae:  0.0443  - val_loss:  0.0018  - val_mae:   0.0337 ]
# Epoch  139 / 200
# ============= [loss:  0.0031  - mae:  0.0445  - val_loss:  0.0018  - val_mae:   0.0339 ]
# Epoch  140 / 200
# ============= [loss:  0.0031  - mae:  0.0446  - val_loss:  0.0018  - val_mae:   0.0342 ]
# Epoch  141 / 200
# ============= [loss:  0.003  - mae:  0.0437  - val_loss:  0.0018  - val_mae:   0.0332 ]
# Epoch  142 / 200
# ============= [loss:  0.003  - mae:  0.045  - val_loss:  0.0019  - val_mae:   0.0349 ]
# Epoch  143 / 200
# ============= [loss:  0.0029  - mae:  0.0431  - val_loss:  0.0018  - val_mae:   0.0326 ]
# Epoch  144 / 200
# ============= [loss:  0.0029  - mae:  0.0428  - val_loss:  0.0018  - val_mae:   0.0322 ]
# Epoch  145 / 200
# ============= [loss:  0.0029  - mae:  0.0444  - val_loss:  0.0019  - val_mae:   0.0345 ]
# Epoch  146 / 200
# ============= [loss:  0.0028  - mae:  0.0431  - val_loss:  0.0018  - val_mae:   0.033 ]
# Epoch  147 / 200
# ============= [loss:  0.0028  - mae:  0.0429  - val_loss:  0.0018  - val_mae:   0.0328 ]
# Epoch  148 / 200
# ============= [loss:  0.0028  - mae:  0.0421  - val_loss:  0.0017  - val_mae:   0.0316 ]
# Epoch  149 / 200
# ============= [loss:  0.0028  - mae:  0.0425  - val_loss:  0.0018  - val_mae:   0.0324 ]
# Epoch  150 / 200
# ============= [loss:  0.0027  - mae:  0.0424  - val_loss:  0.0018  - val_mae:   0.0324 ]
# Epoch  151 / 200
# ============= [loss:  0.0027  - mae:  0.0415  - val_loss:  0.0017  - val_mae:   0.0311 ]
# Epoch  152 / 200
# ============= [loss:  0.0027  - mae:  0.0428  - val_loss:  0.0018  - val_mae:   0.0332 ]
# Epoch  153 / 200
# ============= [loss:  0.0027  - mae:  0.0415  - val_loss:  0.0017  - val_mae:   0.0312 ]
# Epoch  154 / 200
# ============= [loss:  0.0026  - mae:  0.0419  - val_loss:  0.0018  - val_mae:   0.032 ]
# Epoch  155 / 200
# ============= [loss:  0.0026  - mae:  0.0409  - val_loss:  0.0017  - val_mae:   0.0307 ]
# Epoch  156 / 200
# ============= [loss:  0.0026  - mae:  0.0413  - val_loss:  0.0017  - val_mae:   0.0312 ]
# Epoch  157 / 200
# ============= [loss:  0.0026  - mae:  0.042  - val_loss:  0.0018  - val_mae:   0.0327 ]
# Epoch  158 / 200
# ============= [loss:  0.0026  - mae:  0.0425  - val_loss:  0.0019  - val_mae:   0.0336 ]
# Epoch  159 / 200
# ============= [loss:  0.0025  - mae:  0.0411  - val_loss:  0.0018  - val_mae:   0.0312 ]
# Epoch  160 / 200
# ============= [loss:  0.0025  - mae:  0.0418  - val_loss:  0.0018  - val_mae:   0.0327 ]
# Epoch  161 / 200
# ============= [loss:  0.0025  - mae:  0.0402  - val_loss:  0.0018  - val_mae:   0.0306 ]
# Epoch  162 / 200
# ============= [loss:  0.0025  - mae:  0.0417  - val_loss:  0.0018  - val_mae:   0.0327 ]
# Epoch  163 / 200
# ============= [loss:  0.0025  - mae:  0.0414  - val_loss:  0.0018  - val_mae:   0.0322 ]
# Epoch  164 / 200
# ============= [loss:  0.0025  - mae:  0.0404  - val_loss:  0.0018  - val_mae:   0.0307 ]
# Epoch  165 / 200
# ============= [loss:  0.0024  - mae:  0.0409  - val_loss:  0.0018  - val_mae:   0.0315 ]
# Epoch  166 / 200
# ============= [loss:  0.0024  - mae:  0.0398  - val_loss:  0.0018  - val_mae:   0.0308 ]
# Epoch  167 / 200
# ============= [loss:  0.0024  - mae:  0.0402  - val_loss:  0.0018  - val_mae:   0.0308 ]
# Epoch  168 / 200
# ============= [loss:  0.0024  - mae:  0.04  - val_loss:  0.0018  - val_mae:   0.0308 ]
# Epoch  169 / 200
# ============= [loss:  0.0024  - mae:  0.0405  - val_loss:  0.0018  - val_mae:   0.0314 ]
# Epoch  170 / 200
# ============= [loss:  0.0024  - mae:  0.041  - val_loss:  0.0018  - val_mae:   0.0323 ]
# Epoch  171 / 200
# ============= [loss:  0.0024  - mae:  0.0396  - val_loss:  0.0018  - val_mae:   0.031 ]
# Epoch  172 / 200
# ============= [loss:  0.0024  - mae:  0.0396  - val_loss:  0.0018  - val_mae:   0.031 ]
# Epoch  173 / 200
# ============= [loss:  0.0024  - mae:  0.039  - val_loss:  0.0018  - val_mae:   0.0314 ]
# Epoch  174 / 200
# ============= [loss:  0.0023  - mae:  0.0395  - val_loss:  0.0018  - val_mae:   0.0311 ]
# Epoch  175 / 200
# ============= [loss:  0.0023  - mae:  0.0401  - val_loss:  0.0018  - val_mae:   0.0316 ]
# Epoch  176 / 200
# ============= [loss:  0.0023  - mae:  0.0395  - val_loss:  0.0018  - val_mae:   0.0313 ]
# Epoch  177 / 200
# ============= [loss:  0.0023  - mae:  0.0398  - val_loss:  0.0018  - val_mae:   0.0315 ]
# Epoch  178 / 200
# ============= [loss:  0.0023  - mae:  0.0391  - val_loss:  0.0018  - val_mae:   0.0314 ]
# Epoch  179 / 200
# ============= [loss:  0.0023  - mae:  0.0398  - val_loss:  0.0018  - val_mae:   0.0316 ]
# Epoch  180 / 200
# ============= [loss:  0.0023  - mae:  0.0395  - val_loss:  0.0018  - val_mae:   0.0316 ]
# Epoch  181 / 200
# ============= [loss:  0.0023  - mae:  0.0399  - val_loss:  0.0019  - val_mae:   0.0319 ]
# Epoch  182 / 200
# ============= [loss:  0.0023  - mae:  0.0393  - val_loss:  0.0019  - val_mae:   0.0317 ]
# Epoch  183 / 200
# ============= [loss:  0.0023  - mae:  0.0393  - val_loss:  0.0019  - val_mae:   0.0317 ]
# Epoch  184 / 200
# ============= [loss:  0.0023  - mae:  0.0387  - val_loss:  0.0019  - val_mae:   0.0318 ]
# Epoch  185 / 200
# ============= [loss:  0.0022  - mae:  0.0387  - val_loss:  0.0019  - val_mae:   0.0319 ]
# Epoch  186 / 200
# ============= [loss:  0.0023  - mae:  0.0403  - val_loss:  0.0019  - val_mae:   0.033 ]
# Epoch  187 / 200
# ============= [loss:  0.0022  - mae:  0.0383  - val_loss:  0.0019  - val_mae:   0.0322 ]
# Epoch  188 / 200
# ============= [loss:  0.0022  - mae:  0.0387  - val_loss:  0.0019  - val_mae:   0.032 ]
# Epoch  189 / 200
# ============= [loss:  0.0022  - mae:  0.0397  - val_loss:  0.0019  - val_mae:   0.0325 ]
# Epoch  190 / 200
# ============= [loss:  0.0022  - mae:  0.0384  - val_loss:  0.0019  - val_mae:   0.0322 ]
# Epoch  191 / 200
# ============= [loss:  0.0022  - mae:  0.0385  - val_loss:  0.0019  - val_mae:   0.0322 ]
# Epoch  192 / 200
# ============= [loss:  0.0022  - mae:  0.0385  - val_loss:  0.0019  - val_mae:   0.0323 ]
# Epoch  193 / 200
# ============= [loss:  0.0022  - mae:  0.0382  - val_loss:  0.0019  - val_mae:   0.0324 ]
# Epoch  194 / 200
# ============= [loss:  0.0022  - mae:  0.0386  - val_loss:  0.0019  - val_mae:   0.0324 ]
# Epoch  195 / 200
# ============= [loss:  0.0022  - mae:  0.038  - val_loss:  0.0019  - val_mae:   0.0326 ]
# Epoch  196 / 200
# ============= [loss:  0.0022  - mae:  0.0382  - val_loss:  0.0019  - val_mae:   0.0325 ]
# Epoch  197 / 200
# ============= [loss:  0.0022  - mae:  0.0378  - val_loss:  0.002  - val_mae:   0.0328 ]
# Epoch  198 / 200
# ============= [loss:  0.0022  - mae:  0.0376  - val_loss:  0.002  - val_mae:   0.0329 ]
# Epoch  199 / 200
# ============= [loss:  0.0022  - mae:  0.0378  - val_loss:  0.002  - val_mae:   0.0328 ]
# Epoch  200 / 200
# ============= [loss:  0.0022  - mae:  0.0383  - val_loss:  0.0019  - val_mae:   0.0327 ]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import *


# Part 3: Obtaining predictions
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_scaled, test_size=validation_percentage, shuffle=True)
y_pred_test = nn.predict(x_test)
y_pred_train = nn.predict(x_train)

print("---Test---")
print("R2 Score: ", r2_score(y_test, y_pred_test))
print("MSE: ", mean_squared_error(y_test, y_pred_test))
print("MAE: ", mean_absolute_error(y_test, y_pred_test))
print("---Train---")
print("R2 Score: ", r2_score(y_train, y_pred_train))
print("MSE: ", mean_squared_error(y_train, y_pred_train))
print("MAE: ", mean_absolute_error(y_train, y_pred_train))
print("")
print("MAPE: ", mean_absolute_percentage_error(y_test, y_pred_test))

y_test_unscaled = scaler.inverse_transform(y_test)
y_pred_test_unscaled = scaler.inverse_transform(y_pred_test)
y_train_unscaled = scaler.inverse_transform(y_train)
y_pred_train_unscaled = scaler.inverse_transform(y_pred_train)

plt.scatter(y_train_unscaled, y_pred_train_unscaled, color="blue", label="Train")
plt.scatter(y_test_unscaled, y_pred_test_unscaled, color="red", label="Test")
plt.xlabel("actual Values")
plt.ylabel("Predition Values")
plt.title("Actual vs Prediction")
plt.plot(y, y, "--",color="black")
plt.legend()
plt.show()
# Out:
# ---Test---
# R2 Score:  0.9666953835627952
# MSE:  0.002266486201278344
# MAE:  0.038001408336540074
# ---Train---
# R2 Score:  0.9658732796070387
# MSE:  0.002106086398283792
# MAE:  0.037343674391476185
#
# MAPE:  0.17642831695155636
